# %% [markdown]
# This script is soley used to investigate and clean the dataset. We will carry out the visualization in Tableau instead.

# %% [markdown]
# ## 0. Import Libraries

# %%
import pandas as pd
from utils import *

# %% [markdown]
# ## 1. Import Data

# %%
df = pd.read_csv("Meteorite_Landings_20231028.csv")
df.head()
# Out:
#        name   id nametype     recclass  mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902.0 -33.16667
#
#      reclong           GeoLocation
# 0    6.08333     (50.775, 6.08333)
# 1   10.23333  (56.18333, 10.23333)
# 2 -113.00000    (54.21667, -113.0)
# 3  -99.90000     (16.88333, -99.9)
# 4  -64.95000   (-33.16667, -64.95)

# %%
data_cleaning(df)
# Out:
# data shape: (45716, 10)
# <style type="text/css">
# #T_2e97c_row0_col1, #T_2e97c_row0_col2, #T_2e97c_row1_col1, #T_2e97c_row1_col2, #T_2e97c_row2_col1, #T_2e97c_row2_col2, #T_2e97c_row2_col3, #T_2e97c_row3_col1, #T_2e97c_row3_col2, #T_2e97c_row5_col1, #T_2e97c_row5_col2, #T_2e97c_row5_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_2e97c_row0_col3, #T_2e97c_row1_col3, #T_2e97c_row7_col1, #T_2e97c_row7_col2, #T_2e97c_row8_col1, #T_2e97c_row8_col2, #T_2e97c_row9_col1, #T_2e97c_row9_col2 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_2e97c_row3_col3 {
#   background-color: #fffee2;
#   color: #000000;
# }
# #T_2e97c_row4_col1, #T_2e97c_row4_col2 {
#   background-color: #fffee0;
#   color: #000000;
# }
# #T_2e97c_row4_col3 {
#   background-color: #fedd84;
#   color: #000000;
# }
# #T_2e97c_row6_col1, #T_2e97c_row6_col2 {
#   background-color: #fffcd8;
#   color: #000000;
# }
# #T_2e97c_row6_col3 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# ...

# %% [markdown]
# 1. `mass`: Some missing values (0.28%), not too much of a concern as we can later decide either to impute these missing values or remove the rows.
# 2. `year`: Don't think it's a good idea to impute years, perhaps its best to remove these rows IF we were to plot something related to years, OR we could just put NA for these missing values.
# 3. `reclat`, `reclong`: Lots of missing values, as the latitude of longitude of meteorites was not identified.

# %%
df['Fall']

# %%
df_fall = df[df['fall'] == 'Fell']
df_fall.sort_values(by='mass (g)', ascending=False)
# Out:
#                name     id nametype    recclass    mass (g)  fall    year  \
# 920    Sikhote-Alin  23593    Valid  Iron, IIAB  23000000.0  Fell  1947.0
# 419           Jilin  12171    Valid          H5   4000000.0  Fell  1976.0
# 29          Allende   2278    Valid         CV3   2000000.0  Fell  1969.0
# 707   Norton County  17922    Valid     Aubrite   1100000.0  Fell  1948.0
# 506   Kunya-Urgench  12379    Valid          H5   1100000.0  Fell  1998.0
# ...             ...    ...      ...         ...         ...   ...     ...
# 957       Stolzenau  23726    Valid  Stone-uncl         NaN  Fell  1647.0
# 1018   Tulung Dzong  24071    Valid  Stone-uncl         NaN  Fell  1944.0
# 1043      Valdinoce  24146    Valid  Stone-uncl         NaN  Fell  1495.0
# 1054     Villarrica  24181    Valid  Stone-uncl         NaN  Fell  1925.0
# 1079          Wuzhi  24342    Valid  Stone-uncl         NaN  Fell  1931.0
#
#         reclat    reclong             GeoLocation
# ...

# %%
df_fall = df[df['fall'] == 'Fell']
df_fall[df_fall['year'] == 1933].sort_values(by='mass (g)')
# Out:
#                   name     id nametype         recclass  mass (g)  fall  \
# 575             Malaga  15393    Valid               OC     150.0  Fell
# 268      Dyarrl Island   7758    Valid  Mesosiderite-A1     188.0  Fell
# 144             Brient   5140    Valid    Eucrite-pmict     219.0  Fell
# 712        Noyan-Bogdo  17936    Valid               L6     250.0  Fell
# 54              Athens   4885    Valid              LL6     265.0  Fell
# 74              Banten   4938    Valid              CM2     629.0  Fell
# 811       Po-wang Chen  18879    Valid               LL     665.0  Fell
# 579            Malvern  15400    Valid    Eucrite-pmict     807.0  Fell
# 784           Pesyanoe  18799    Valid          Aubrite    3393.0  Fell
# 927       Sioux County  23614    Valid    Eucrite-mmict    4100.0  Fell
# 766          Pasamonte  18110    Valid    Eucrite-pmict    5100.0  Fell
# 847      Repeev Khutor  22590    Valid        Iron, IIF    7000.0  Fell
# ...

# %%
df[df['name'] == 'Hoba']
# Out:
#        name     id nametype   recclass    mass (g)   fall    year    reclat  \
# 16392  Hoba  11890    Valid  Iron, IVB  60000000.0  Found  1920.0 -19.58333
#
#         reclong            GeoLocation
# 16392  17.91667  (-19.58333, 17.91667)
