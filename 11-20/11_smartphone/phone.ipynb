# %%
import os
os.listdir()
# Out:
# ['smartphones.csv', '.DS_Store', 'phone.ipynb']

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd

df = pd.read_csv('smartphones.csv')
df.head()
# Out:
#   brand_name                    model   price  avg_rating  5G_or_not  \
# 0      apple          Apple iPhone 11   38999         7.3          0
# 1      apple  Apple iPhone 11 (128GB)   46999         7.5          0
# 2      apple  Apple iPhone 11 Pro Max  109900         7.7          0
# 3      apple          Apple iPhone 12   51999         7.4          1
# 4      apple  Apple iPhone 12 (128GB)   55999         7.5          1
#
#   processor_brand  num_cores  processor_speed  battery_capacity  \
# 0          bionic        6.0             2.65            3110.0
# 1          bionic        6.0             2.65            3110.0
# 2          bionic        6.0             2.65            3500.0
# 3          bionic        6.0             3.10               NaN
# 4          bionic        6.0             3.10               NaN
#
#    fast_charging_available  ...  internal_memory  screen_size  refresh_rate  \
# 0                        0  ...               64          6.1            60
# ...

# %%
# Find out how to find orrelation between categorical variables and the price

df['processor_brand'].value_counts()
# Out:
# snapdragon    413
# helio         201
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: processor_brand, dtype: int64

# %% [markdown]
# ### Let's explore the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   avg_rating                 879 non-null    float64
#  4   5G_or_not                  980 non-null    int64
#  5   processor_brand            960 non-null    object
#  6   num_cores                  974 non-null    float64
#  7   processor_speed            938 non-null    float64
#  8   battery_capacity           969 non-null    float64
#  9   fast_charging_available    980 non-null    int64
#  10  fast_charging              769 non-null    float64
#  11  ram_capacity               980 non-null    int64
#  12  internal_memory            980 non-null    int64
# ...

# %% [markdown]
# Columns with missing values: `avg_rating`, `processor_brand`, `num_cores`, `processor_speed`, `battery_capacity`, `fast_charging`, `os`, `primary_camera_front`

# %%
df.describe()
# Out:
#                price  avg_rating   5G_or_not   num_cores  processor_speed  \
# count     980.000000  879.000000  980.000000  974.000000       938.000000
# mean    32520.504082    7.825825    0.560204    7.772074         2.427217
# std     39531.812669    0.740285    0.496616    0.836845         0.464090
# min      3499.000000    6.000000    0.000000    4.000000         1.200000
# 25%     12999.000000    7.400000    0.000000    8.000000         2.050000
# 50%     19994.500000    8.000000    1.000000    8.000000         2.300000
# 75%     35491.500000    8.400000    1.000000    8.000000         2.840000
# max    650000.000000    8.900000    1.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# ...

# %% [markdown]
# ### Data Visualisation

# %% [markdown]
# Plotting average price for different brand names

# %%
import matplotlib.pyplot as plt

# %%
avg_price = df.groupby('brand_name')['price'].mean().reset_index()
avg_price = avg_price.sort_values(by='price', ascending=False).reset_index(drop=True)

# %%
avg_price['price'] = avg_price['price'] / 100

plt.bar(avg_price['brand_name'], avg_price['price'])
plt.xlabel('Brand Names')
plt.ylabel('Price in USD ($)')
plt.title("Average Price ($) of Different Smartphone Brands")
# Out:
# Text(0.5, 1.0, 'Average Price ($) of Different Smartphone Brands')

# %% [markdown]
# Plotting the average ratings for different brand names

# %%
avg_rating = df.groupby('brand_name')['avg_rating'].mean().reset_index()
avg_rating = avg_rating.sort_values(by='avg_rating', ascending=False).reset_index(drop=True)

# %%
# Plot
top_10_avg = avg_rating.head(n=10)


plt.bar(avg_rating['brand_name'], avg_rating['avg_rating'])
plt.xlabel("Brand Name")
plt.ylabel("Average Rating")
plt.title("Average Rating of Different Smartphone Brands")
plt.show()

# %%
# Out:
# <AxesSubplot: xlabel='brand_name', ylabel='avg_rating'>

# %% [markdown]
# Find out if phones with higher price have higher ratings

# %%
plt.scatter(df['price']/100, df['avg_rating'])
plt.xlabel('Price')
plt.ylabel('Average Rating')
plt.title("Relationship between Smartphone Prices and its Ratings")
# Out:
# Text(0.5, 1.0, 'Relationship between Smartphone Prices and its Ratings')

# %%
a = df[df['price']/100 <= 500] 
b = a[a['avg_rating'] >= 8.9]
b
# Out:
#     brand_name                                    model  price  avg_rating  \
# 136    infinix                       Infinix Zero Ultra  36999         8.9
# 207   motorola                  Motorola Edge 30 Pro 5G  34999         8.9
# 251   motorola                        Motorola Moto X40  39999         8.9
# 254   motorola                      Motorola ThinkPhone  49990         8.9
# 513     realme                       Realme GT 2 Pro 5G  49959         8.9
# 514     realme    Realme GT 2 Pro 5G (12GB RAM + 256GB)  46999         8.9
# 597    samsung     Samsung Galaxy A53 (8GB RAM + 256GB)  36499         8.9
# 599    samsung  Samsung Galaxy A53 5G (8GB RAM + 128GB)  33499         8.9
# 708      tecno                     Tecno Phantom X2 Pro  49999         8.9
# 855     xiaomi                             Xiaomi 13 5G  46990         8.9
# 958     xiaomi            Xiaomi Redmi Note 12 Explorer  24999         8.9
#
# ...

# %% [markdown]
# ### Further analysis

# %% [markdown]
# Some analysis plans in mind:
# 1. Find out the brands that stand out the most in terms of numerate categories
# 2. Do a correlation heatmap to see what cateogory correlates to price the most, then plot the category individually

# %%
sns.barplo
